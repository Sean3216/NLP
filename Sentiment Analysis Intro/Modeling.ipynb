# %%
#essentials
import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns

# %%
con = sqlite3.connect('database.sqlite')
raw = pd.read_sql_query("select ProductId,ProfileName, HelpfulnessNumerator, HelpfulnessDenominator, Time, Text, case when Score >= 4 then 1 else 0 end Sentiment from Reviews", con)
con.close()

# %%
raw
# Out:
#          ProductId                      ProfileName  HelpfulnessNumerator  \
# 0       B001E4KFG0                       delmartian                     1
# 1       B00813GRG4                           dll pa                     0
# 2       B000LQOCH0  Natalia Corres "Natalia Corres"                     1
# 3       B000UA0QIQ                             Karl                     3
# 4       B006K2ZZ7K    Michael D. Bigham "M. Wassir"                     0
# ...            ...                              ...                   ...
# 568449  B001EO7N10                 Lettie D. Carter                     0
# 568450  B003S1WTCU                        R. Sawyer                     0
# 568451  B004I613EE                    pksd "pk_007"                     2
# 568452  B004I613EE          Kathy A. Welch "katwel"                     1
# 568453  B001LR2CU2                         srfell17                     0
#
#         HelpfulnessDenominator        Time  \
# 0                            1  1303862400
# 1                            0  1346976000
# 2                            1  1219017600
# 3                            3  1307923200
# 4                            0  1350777600
# ...                        ...         ...
# 568449                       0  1299628800
# 568450                       0  1331251200
# 568451                       2  1329782400
# 568452                       1  1331596800
# 568453                       0  1338422400
#
#                                                      Text  Sentiment
# 0       I have bought several of the Vitality canned d...          1
# 1       Product arrived labeled as Jumbo Salted Peanut...          0
# 2       This is a confection that has been around a fe...          1
# 3       If you are looking for the secret ingredient i...          0
# 4       Great taffy at a great price.  There was a wid...          1
# ...                                                   ...        ...
# 568449  Great for sesame chicken..this is a good if no...          1
# 568450  I'm disappointed with the flavor. The chocolat...          0
# 568451  These stars are small, so you can give 10-15 o...          1
# 568452  These are the BEST treats for training and rew...          1
# 568453  I am very satisfied ,product is as advertised,...          1
#
# [568454 rows x 7 columns]

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# We understand from the previous EDA that we need to handle clean ProfileName and add 3 new variables(user review frequency, product review frequency, spam frequency). This all will be done within the preprocessing step.

# %% [markdown]
# We first split the data into 3 parts before preprocessing them. We split them into train data, test data, and validation data.

# %%
from sklearn.model_selection import train_test_split
xtrain, xsplit, ytrain, ysplit = train_test_split(raw.drop('Sentiment',axis = 1),
                                                  raw.Sentiment, 
                                                  test_size = 0.3, 
                                                  random_state = 42)
xtest, xval, ytest, yval = train_test_split(xsplit,ysplit,
                                            test_size = 0.5,
                                            random_state = 42)

# %%
from gensim.models.word2vec import Word2Vec
#install python-Levenshtein too if you haven't already did

#===========================================================================#
#                         TOKENIZATION FUNCTION                             #
#===========================================================================#

def tokenize(txt):
    import re
    from wordcloud import STOPWORDS
    import nltk
    from nltk.tokenize import word_tokenize
    from nltk.stem.wordnet import WordNetLemmatizer
    stpwrd = set(STOPWORDS)
    #we then add frequent irrelevant words discovered before 
    stpwrd.update(['br','href','amazon','product','one','find','taste','flavor','good','buy','make','coffee'])
    removeapos = txt.lower().replace("'",'') #remove any apostrophe
    text = re.sub(r"[^a-zA-Z0-9\s]"," ", removeapos) #sub with space for any weird char
    words = word_tokenize(text)
    lemma = [WordNetLemmatizer().lemmatize(w) for w in words if w not in stpwrd]
    return lemma



#===========================================================================#
#                         PREPROCESS AND ENGINEER                           #
#===========================================================================#

def preprocess_engineer(data,train = True):
    #this is to handle missing values before using the data
    data['ProfileName'] = data['ProfileName'].apply(lambda x: 'Anonymous' if 
                                                (x == 'nan')|(x == 'NaN')|
                                                (x == 'N/A')|(x == '0')|
                                                (x == '')|(x == '-1')|
                                                (x == 'null')|(x == 'Null')|
                                                (x == 'NA')|(x == 'na')|
                                                (x == 'none')|(x == 'unknown') else x)
    #this is to simulate that after data train, we face a number of new reviews
    if train == True:
        countprof = data.ProfileName.value_counts().reset_index()
        countprof.columns = ['ProfileName','ProfReviewCount']
        
        countprod = data.ProductId.value_counts().reset_index()
        countprod.columns = ['ProductId','ProdReviewCount']
        
        countspam = data.groupby(['ProductId','ProfileName']).size().reset_index()
        countspam.columns = ['ProductId','ProfileName','SpamReviewCount']
        
        engineered = pd.merge(
                        pd.merge(
                            pd.merge(data,countprof,how='left',on='ProfileName'),
                            countprod,how = 'left', on = 'ProductId'),
                        countspam, how = 'left',on = ['ProductId','ProfileName'])
        return engineered      
    if train == False:
        #this is from train
        countproftrain = xtrain.ProfileName.value_counts().reset_index()
        countproftrain.columns = ['ProfileName','ProfReviewCounttrain']
        
        countprodtrain = xtrain.ProductId.value_counts().reset_index()
        countprodtrain.columns = ['ProductId','ProdReviewCounttrain']
        
        countspamtrain = xtrain.groupby(['ProductId','ProfileName']).size().reset_index()
        countspamtrain.columns = ['ProductId','ProfileName','SpamReviewCounttrain']
        
        
        
        #this is from the newly introduced data
        countprof = data.ProfileName.value_counts().reset_index()
        countprof.columns = ['ProfileName','ProfReviewCountadd']
        
        countprod = data.ProductId.value_counts().reset_index()
        countprod.columns = ['ProductId','ProdReviewCountadd']
        
        countspam = data.groupby(['ProductId','ProfileName']).size().reset_index()
        countspam.columns = ['ProductId','ProfileName','SpamReviewCountadd']
        
        
        
        #this is to add newly introduced data with train
        #ProfileName
        countproffinal = countprof.merge(countproftrain,how = 'left',on = 'ProfileName')
        countproffinal.fillna(0,inplace = True)
        countproffinal['ProfReviewCount'] = countproffinal.ProfReviewCounttrain + countproffinal.ProfReviewCountadd
        countproffinal.drop(['ProfReviewCounttrain','ProfReviewCountadd'],axis = 1,inplace = True)
    
        #ProductId
        countprodfinal = countprod.merge(countprodtrain,how = 'left',on = 'ProductId')
        countprodfinal.fillna(0,inplace = True)
        countprodfinal['ProdReviewCount'] = countprodfinal.ProdReviewCounttrain + countprodfinal.ProdReviewCountadd
        countprodfinal.drop(['ProdReviewCounttrain','ProdReviewCountadd'],axis = 1,inplace = True)
        
        #SpamReviewCount
        countspamfinal = countspam.merge(countspamtrain,how = 'left',on = ['ProductId','ProfileName'])
        countspamfinal.fillna(0,inplace = True)
        countspamfinal['SpamReviewCount'] = countspamfinal.SpamReviewCounttrain + countspamfinal.SpamReviewCountadd
        countspamfinal.drop(['SpamReviewCounttrain','SpamReviewCountadd'],axis = 1,inplace = True)
        
        engineered = pd.merge(
                        pd.merge(
                            pd.merge(data,countproffinal,how='left',on='ProfileName'),
                            countprodfinal,how = 'left', on = 'ProductId'),
                        countspamfinal, how = 'left',on = ['ProductId','ProfileName'])
        return engineered

# %%
xtrainpreprocessed = preprocess_engineer(xtrain,train = True)
xtestpreprocessed = preprocess_engineer(xtest,train = False)
xvalpreprocessed = preprocess_engineer(xval,train = False)
# Out:
# C:\Users\921000~1\AppData\Local\Temp/ipykernel_10948/352955635.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ProfileName'] = data['ProfileName'].apply(lambda x: 'Anonymous' if

# %%
#function to average
def AverageVectors(wordvectmod,oritokenizedtxt):
    todict = dict(zip(wordvectmod.wv.index_to_key,wordvectmod.wv.vectors))
    #if a text is empty we should return a vector of zeros
    #with the same dimensionality as all the other vectors
    dim = len(next(iter(todict.values())))
    return np.array([np.mean([todict[w] for w in words if w in todict]
                              or 
                             [np.zeros(dim)],axis = 0)
                     for words in oritokenizedtxt
                    ])

w2v = Word2Vec(xtrainpreprocessed.Text.apply(tokenize),
                 sg = 0,
                 hs = 1,
                 seed = 42,
                 vector_size = 128)
#convert to vect average
xtrainvect = AverageVectors(w2v,xtrainpreprocessed.Text.apply(tokenize))
xtestvect = AverageVectors(w2v,xtestpreprocessed.Text.apply(tokenize))
xvalvect = AverageVectors(w2v,xvalpreprocessed.Text.apply(tokenize))

# %%
#add the remaining features
def vecttodata(aftervec,beforevec):
    df = pd.DataFrame(aftervec)
    df['HelpfulnessNumerator'] = beforevec.reset_index(drop=True)['HelpfulnessNumerator']
    df['HelpfulnessDenominator'] = beforevec.reset_index(drop=True)['HelpfulnessNumerator']
    df['Time'] = beforevec.reset_index(drop=True)['Time']
    df['ProfReviewCount'] = beforevec.reset_index(drop=True)['ProfReviewCount']
    df['ProdReviewCount'] = beforevec.reset_index(drop=True)['ProdReviewCount']
    df['SpamReviewCount'] = beforevec.reset_index(drop=True)['SpamReviewCount'] 
    
    return df
    
xtraindf = vecttodata(xtrainvect,xtrainpreprocessed)
xtestdf = vecttodata(xtestvect,xtestpreprocessed)
xvaldf = vecttodata(xvalvect,xvalpreprocessed)

# %%
from xgboost import XGBClassifier
from sklearn.utils.class_weight import compute_sample_weight


sample_weights = compute_sample_weight(
    class_weight='balanced',
    y=ytrain
)

xgb = XGBClassifier(booster = 'gbtree',
                    objective = 'binary:logistic',
                    eval_metric='auc',
                    seed = 42, use_label_encoder = False,
                    num_parallel_tree = 10,
                    n_estimators = 50,
                    verbosity = 2)
xgb.fit(xtraindf,ytrain,sample_weight = sample_weights)
pred = xgb.predict(xtestdf)
from sklearn.metrics import confusion_matrix,classification_report
print(classification_report(pred,ytest, target_names = ['Negative','Positive']))
# Out:
# [15:18:20] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:18:20] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:18:20] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:18:20] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:18:20] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:18:20] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:18:20] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:18:20] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:18:20] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:18:20] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:19:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:19:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:19:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:19:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:19:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:19:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:19:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:19:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:19:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:19:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:20:34] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:20:34] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:20:34] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:20:34] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:20:34] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:20:34] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:20:34] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:20:34] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:20:34] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:20:34] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:21:39] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:21:39] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:21:39] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:21:39] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:21:39] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:21:39] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:21:39] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:21:39] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:21:39] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:21:39] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:22:40] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:22:40] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:22:40] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:22:40] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:22:40] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:22:40] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:22:40] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:22:40] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:22:40] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:22:40] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:23:38] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:23:38] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:23:38] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:23:38] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:23:38] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:23:38] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:23:38] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:23:38] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:23:38] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:23:38] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:24:36] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:24:36] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:24:36] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:24:36] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:24:36] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:24:36] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:24:36] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:24:36] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:24:36] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:24:36] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:25:33] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:25:33] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:25:33] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:25:33] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:25:33] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:25:33] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:25:33] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:25:33] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:25:33] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:25:33] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:26:31] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:26:31] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:26:31] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:26:31] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:26:31] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:26:31] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:26:31] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:26:31] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:26:31] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:26:31] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:27:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:27:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:27:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:27:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:27:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:27:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:27:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:27:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:27:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:27:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:28:28] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:28:28] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:28:28] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:28:28] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:28:28] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:28:28] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:28:28] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:28:28] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:28:28] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:28:28] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:29:28] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:29:28] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:29:28] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:29:28] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:29:28] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:29:28] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:29:28] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:29:28] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:29:28] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:29:28] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:30:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:30:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:30:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:30:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:30:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:30:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:30:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:30:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:30:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:30:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:31:23] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:31:23] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:31:23] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:31:23] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:31:23] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:31:23] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:31:23] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:31:23] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:31:23] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:31:23] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:32:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [15:32:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [15:32:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [15:32:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [15:32:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [15:32:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [15:32:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [15:32:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [15:32:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [15:32:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [15:33:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:33:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:33:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:33:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:33:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:33:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:33:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:33:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:33:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:33:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:34:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:34:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:34:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:34:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:34:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:34:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:34:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:34:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:34:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:34:26] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:35:25] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:35:25] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:35:25] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:35:25] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:35:25] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:35:25] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:35:25] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:35:25] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:35:25] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:35:25] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:36:24] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:36:24] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:36:24] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:36:24] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:36:24] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:36:24] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:36:24] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:36:24] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:36:24] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:36:24] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:37:22] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:37:22] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:37:22] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:37:22] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:37:22] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:37:22] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:37:22] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:37:22] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:37:22] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:37:22] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:38:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:38:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:38:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:38:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:38:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:38:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:38:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:38:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:38:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:38:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:39:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:39:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:39:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:39:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:39:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:39:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:39:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:39:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:39:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:39:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:40:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:40:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:40:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:40:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:40:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:40:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:40:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:40:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:40:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:40:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:41:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:41:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:41:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:41:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:41:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:41:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:41:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:41:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:41:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:41:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:42:19] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:42:19] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:42:19] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:42:19] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:42:19] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:42:19] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:42:19] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:42:19] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:42:19] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:42:19] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:43:18] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:43:18] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:43:18] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:43:18] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:43:18] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:43:18] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:43:18] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:43:18] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:43:18] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:43:18] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:44:16] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:44:16] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:44:16] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:44:16] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:44:16] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:44:16] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:44:16] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:44:16] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:44:16] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:44:16] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:45:14] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:45:14] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:45:14] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:45:14] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:45:14] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:45:14] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:45:14] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:45:14] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:45:14] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:45:14] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:46:14] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [15:46:14] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [15:46:14] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [15:46:14] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [15:46:14] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [15:46:14] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [15:46:14] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [15:46:14] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [15:46:14] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [15:46:14] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 120 extra nodes, 0 pruned nodes, max_depth=6
# [15:47:16] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:47:16] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:47:16] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:47:16] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:47:16] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:47:16] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:47:16] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:47:16] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:47:16] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:47:16] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:48:23] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:48:23] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:48:23] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:48:23] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:48:23] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:48:23] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:48:23] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:48:23] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:48:23] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:48:23] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:49:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:49:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:49:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:49:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:49:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:49:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:49:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:49:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:49:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:49:29] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:50:34] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:50:34] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:50:34] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:50:34] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:50:34] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:50:34] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:50:34] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:50:34] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:50:34] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:50:34] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:51:39] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:51:39] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:51:39] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:51:39] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:51:39] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:51:39] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:51:39] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:51:39] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:51:39] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:51:39] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:52:45] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:52:45] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:52:45] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:52:45] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:52:45] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:52:45] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:52:45] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:52:45] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:52:45] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:52:45] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:53:50] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:53:50] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:53:50] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:53:50] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:53:50] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:53:50] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:53:50] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:53:50] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:53:50] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:53:50] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:54:48] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:54:48] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:54:48] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:54:48] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:54:48] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:54:48] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:54:48] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:54:48] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:54:48] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:54:48] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:55:46] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:55:46] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:55:46] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:55:46] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:55:46] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:55:46] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:55:46] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:55:46] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:55:46] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:55:46] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:56:42] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:56:42] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:56:42] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:56:42] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:56:42] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:56:42] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:56:42] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:56:42] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:56:42] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:56:42] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:57:41] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [15:57:41] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [15:57:41] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [15:57:41] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [15:57:41] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [15:57:41] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [15:57:41] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [15:57:41] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [15:57:41] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [15:57:41] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [15:58:44] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:58:44] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:58:44] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:58:44] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:58:44] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:58:44] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:58:44] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:58:44] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:58:44] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:58:44] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [15:59:47] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:59:47] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:59:47] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:59:47] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:59:47] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:59:47] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:59:47] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:59:47] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:59:47] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [15:59:47] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 124 extra nodes, 0 pruned nodes, max_depth=6
# [16:00:53] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [16:00:53] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [16:00:53] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [16:00:53] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [16:00:53] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [16:00:53] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [16:00:53] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [16:00:53] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [16:00:53] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [16:00:53] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [16:01:57] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:01:57] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:01:57] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:01:57] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:01:57] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:01:57] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:01:57] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:01:57] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:01:57] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:01:57] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:03:02] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:03:02] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:03:02] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:03:02] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:03:02] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:03:02] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:03:02] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:03:02] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:03:02] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:03:02] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:04:07] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:04:07] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:04:07] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:04:07] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:04:07] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:04:07] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:04:07] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:04:07] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:04:07] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:04:07] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:05:11] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:05:11] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:05:11] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:05:11] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:05:11] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:05:11] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:05:11] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:05:11] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:05:11] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:05:11] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:06:17] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:06:17] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:06:17] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:06:17] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:06:17] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:06:17] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:06:17] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:06:17] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:06:17] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:06:17] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:07:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [16:07:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [16:07:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [16:07:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [16:07:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [16:07:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [16:07:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [16:07:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [16:07:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [16:07:21] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=6
# [16:08:30] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:08:30] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:08:30] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:08:30] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:08:30] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:08:30] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:08:30] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:08:30] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:08:30] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
# [16:08:30] INFO: ..\src\tree\updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=6
#               precision    recall  f1-score   support
#
#     Negative       0.83      0.59      0.69     26185
#     Positive       0.84      0.95      0.89     59083
#
#     accuracy                           0.84     85268
#    macro avg       0.84      0.77      0.79     85268
# weighted avg       0.84      0.84      0.83     85268

# %%
#now to test against purely another unseen data

finalpred = xgb.predict(xvaldf)
print(classification_report(finalpred,yval, target_names = ['Negative','Positive']))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.83      0.59      0.69     26183
#     Positive       0.84      0.95      0.89     59086
#
#     accuracy                           0.84     85269
#    macro avg       0.84      0.77      0.79     85269
# weighted avg       0.84      0.84      0.83     85269

# %%
ytrain.value_counts()/len(ytrain)
# Out:
# 1    0.779982
# 0    0.220018
# Name: Sentiment, dtype: float64

# %%
w2v.wv.most_similar(positive = ['great'])
# Out:
# [('fantastic', 0.7873159646987915),
#  ('awesome', 0.7808070182800293),
#  ('excellent', 0.7499616742134094),
#  ('terrific', 0.7298294901847839),
#  ('wonderful', 0.7185574769973755),
#  ('perfect', 0.6669865846633911),
#  ('nice', 0.666668176651001),
#  ('fabulous', 0.6406859755516052),
#  ('amazing', 0.6298671364784241),
#  ('outstanding', 0.5465767979621887)]

# %%
w2v.wv.similarity('great','awesome')
# Out:
# 0.780807

# %%
#cosine similarity manual
v1 = w2v.wv['great']
v2 = w2v.wv['awesome']
np.dot(v1, v2)/(np.linalg.norm(v1)*np.linalg.norm(v2))
# Out:
# 0.7808069

# %%
np.corrcoef(v1,v2)
# Out:
# array([[1.        , 0.77698464],
#        [0.77698464, 1.        ]])

# %%
coba = xtrainpreprocessed.Text.apply(tokenize)

# %%
coba
# Out:
# 0         [found, store, discontinued, great, alternativ...
# 1         [tried, 2, 3, alternative, product, senseo, ma...
# 2         [let, way, regularly, pop, whole, habanero, pe...
# 3         [absolutely, love, bbq, popchips, favorite, sa...
# 4         [bar, 5, box, time, feed, 1, 3, year, old, nig...
#                                 ...
# 397912    [gourmet, one, fair, havent, tried, plain, rec...
# 397913    [bought, kid, eating, really, unlike, regular,...
# 397914    [eight, oclock, make, great, balance, decaf, r...
# 397915    [already, liked, regular, stash, earl, grey, d...
# 397916    [5, 7, dog, given, time, sometimes, feeding, m...
# Name: Text, Length: 397917, dtype: object

# %%
xtrainvect.shape
# Out:
# (397917, 128)

# %%
w2v.wv.index_to_key
# Out:
# ['great',
#  'love',
#  'food',
#  'tea',
#  'will',
#  'dog',
#  'really',
#  'time',
#  'dont',
#  'much',
#  'cup',
#  'bag',
#  'use',
#  'little',
#  'price',
#  'best',
#  'tried',
#  'im',
#  'well',
#  'even',
#  'ive',
#  'better',
#  'try',
#  'now',
#  'day',
#  'eat',
#  'store',
#  'treat',
#  'box',
#  'cat',
#  'chocolate',
#  'water',
#  'first',
#  'drink',
#  '2',
#  'year',
#  'sugar',
#  'brand',
#  'go',
#  'used',
#  'sweet',
#  'found',
#  'way',
#  'made',
#  'think',
#  'give',
#  'free',
#  'bought',
#  '1',
#  'thing',
#  'two',
#  '3',
#  'bit',
#  'say',
#  'order',
#  'know',
#  'taste',
#  'still',
#  'favorite',
#  'ingredient',
#  'mix',
#  'lot',
#  'chip',
#  'snack',
#  'got',
#  '5',
#  'recommend',
#  'want',
#  'work',
#  'bar',
#  'many',
#  'pack',
#  'nice',
#  'delicious',
#  'add',
#  'flavor',
#  'cant',
#  'never',
#  'need',
#  'keep',
#  'every',
#  'something',
#  'hot',
#  'come',
#  'stuff',
#  '4',
#  'review',
#  'didnt',
#  'organic',
#  'without',
#  'always',
#  'quality',
#  'make',
#  'right',
#  'healthy',
#  'le',
#  'milk',
#  'take',
#  'doesnt',
#  'different',
#  'enough',
#  'back',
#  'package',
#  'small',
#  'old',
#  'oil',
#  'calorie',
#  'month',
#  'product',
#  'perfect',
#  'ordered',
#  'bad',
#  'strong',
#  'eating',
#  'put',
#  'salt',
#  'sure',
#  'though',
#  'green',
#  'using',
#  'easy',
#  'smell',
#  'high',
#  'problem',
#  'hard',
#  'fresh',
#  'long',
#  'whole',
#  'see',
#  'size',
#  'enjoy',
#  'natural',
#  'definitely',
#  'thought',
#  'buying',
#  'sauce',
#  'regular',
#  'chicken',
#  'cooky',
#  'bottle',
#  'far',
#  'last',
#  'pretty',
#  'happy',
#  'looking',
#  'diet',
#  'local',
#  'actually',
#  'feel',
#  'people',
#  'star',
#  'another',
#  'look',
#  'big',
#  'going',
#  'fat',
#  'new',
#  'tasty',
#  'shipping',
#  'butter',
#  'quite',
#  'real',
#  'kind',
#  '6',
#  'purchase',
#  'may',
#  'almost',
#  'highly',
#  'wonderful',
#  'amount',
#  'low',
#  'around',
#  'texture',
#  'fruit',
#  'dry',
#  'item',
#  'per',
#  'protein',
#  'anything',
#  'tasted',
#  'blend',
#  'purchased',
#  'tasting',
#  'week',
#  'excellent',
#  'gluten',
#  'bean',
#  'variety',
#  'thats',
#  'worth',
#  'half',
#  'morning',
#  'expensive',
#  'candy',
#  'cereal',
#  'trying',
#  'help',
#  'case',
#  'coconut',
#  'rice',
#  'company',
#  'u',
#  'dark',
#  'grocery',
#  'peanut',
#  'full',
#  'said',
#  'getting',
#  'vanilla',
#  'probably',
#  'kid',
#  'several',
#  'away',
#  'came',
#  'theyre',
#  'wont',
#  'usually',
#  'friend',
#  'family',
#  'id',
#  'added',
#  'meal',
#  'home',
#  'loved',
#  'might',
#  'received',
#  'flavored',
#  'ill',
#  'piece',
#  'health',
#  'seems',
#  'three',
#  '10',
#  'ounce',
#  'black',
#  'isnt',
#  'cost',
#  'money',
#  'light',
#  'serving',
#  'top',
#  'nothing',
#  'minute',
#  'youre',
#  'making',
#  'save',
#  '12',
#  'drinking',
#  'large',
#  'instead',
#  'able',
#  'especially',
#  'one',
#  'bitter',
#  'fact',
#  'cheese',
#  'available',
#  'arrived',
#  'baby',
#  'extra',
#  'corn',
#  'maybe',
#  'disappointed',
#  'roast',
#  'husband',
#  'least',
#  'type',
#  'packaging',
#  'nut',
#  'deal',
#  '8',
#  'fine',
#  'oz',
#  'honey',
#  'others',
#  'gp',
#  'either',
#  'meat',
#  'popcorn',
#  'let',
#  'syrup',
#  'almond',
#  'cream',
#  'recommended',
#  'recipe',
#  'absolutely',
#  'second',
#  'decided',
#  'soup',
#  'next',
#  'energy',
#  'juice',
#  'house',
#  'smooth',
#  'spice',
#  'gave',
#  'prefer',
#  'potato',
#  'started',
#  'chew',
#  'wish',
#  'liked',
#  'went',
#  'grain',
#  'couple',
#  'breakfast',
#  'hour',
#  'powder',
#  'bread',
#  'pod',
#  'white',
#  'open',
#  'wanted',
#  'cheaper',
#  'hand',
#  'ago',
#  'wasnt',
#  'packet',
#  'read',
#  'although',
#  'seem',
#  'yet',
#  'plus',
#  'rich',
#  'quickly',
#  'side',
#  'took',
#  'stick',
#  'bold',
#  'longer',
#  'gift',
#  'can',
#  'must',
#  'pet',
#  'red',
#  'container',
#  'ordering',
#  'fan',
#  'cookie',
#  'mouth',
#  'soft',
#  'fast',
#  'amazing',
#  'life',
#  'jar',
#  'issue',
#  'weight',
#  'part',
#  'end',
#  'keurig',
#  'reason',
#  'rather',
#  'etc',
#  'anyone',
#  'couldnt',
#  'everything',
#  'pound',
#  'pasta',
#  'brew',
#  'spicy',
#  'cracker',
#  'son',
#  'quick',
#  'glad',
#  'tell',
#  'difference',
#  'starbucks',
#  'leaf',
#  'start',
#  'wheat',
#  'plastic',
#  'value',
#  'market',
#  'choice',
#  'beef',
#  'color',
#  'version',
#  'place',
#  'machine',
#  'sometimes',
#  'dried',
#  'cinnamon',
#  'ground',
#  'like',
#  'hair',
#  'ginger',
#  'youll',
#  'wouldnt',
#  '100',
#  'cold',
#  'formula',
#  'vitamin',
#  'everyone',
#  'bite',
#  'mixed',
#  'bowl',
#  'crunchy',
#  'ice',
#  'feed',
#  'cut',
#  'jerky',
#  'cake',
#  'apple',
#  'super',
#  'seed',
#  'alternative',
#  'line',
#  'thank',
#  'run',
#  'vet',
#  'opened',
#  'pepper',
#  'daughter',
#  'believe',
#  'fiber',
#  'canned',
#  'get',
#  'night',
#  'havent',
#  'teeth',
#  'overall',
#  'often',
#  'care',
#  'online',
#  'mean',
#  'ok',
#  'lemon',
#  'salty',
#  '50',
#  'date',
#  'single',
#  'thanks',
#  'cook',
#  'giving',
#  'slightly',
#  'easily',
#  'cooking',
#  'brown',
#  'enjoyed',
#  'coffee',
#  'yummy',
#  'soy',
#  'result',
#  'hope',
#  'artificial',
#  'left',
#  'noodle',
#  'change',
#  'clean',
#  'blue',
#  'guess',
#  'french',
#  'smaller',
#  'list',
#  'soda',
#  '20',
#  'flour',
#  'awesome',
#  'course',
#  'four',
#  '7',
#  'reviewer',
#  'sweetener',
#  'plain',
#  'aftertaste',
#  'gum',
#  'content',
#  'sodium',
#  'exactly',
#  'experience',
#  'oatmeal',
#  'cocoa',
#  'caffeine',
#  'body',
#  'similar',
#  'stomach',
#  'original',
#  'wrong',
#  'aroma',
#  'wife',
#  'recently',
#  'pay',
#  'decaf',
#  'dish',
#  'special',
#  'daily',
#  'close',
#  'label',
#  'surprised',
#  'simply',
#  'yes',
#  'there',
#  'carry',
#  'orange',
#  'pop',
#  'bone',
#  'pleased',
#  'benefit',
#  'heat',
#  'inside',
#  'idea',
#  'compared',
#  'past',
#  'subscribe',
#  'feeding',
#  'picky',
#  'non',
#  'ate',
#  'mild',
#  'contains',
#  'already',
#  'flavorful',
#  'medium',
#  'delivery',
#  'saw',
#  'point',
#  'service',
#  'maker',
#  'someone',
#  'finally',
#  'note',
#  'huge',
#  '15',
#  'option',
#  'based',
#  'noticed',
#  'gone',
#  'olive',
#  'looked',
#  'espresso',
#  'sell',
#  'fish',
#  'gram',
#  'due',
#  'unfortunately',
#  'along',
#  'later',
#  'live',
#  'pot',
#  'salad',
#  'needed',
#  'expected',
#  'packaged',
#  'toy',
#  'customer',
#  'arent',
#  'lunch',
#  'pill',
#  'done',
#  'name',
#  'adding',
#  'instant',
#  'bottom',
#  'skin',
#  'seasoning',
#  'please',
#  'lb',
#  'raw',
#  'given',
#  'leave',
#  'stay',
#  'larger',
#  'convenient',
#  'soon',
#  'pouch',
#  'cherry',
#  'allergy',
#  'egg',
#  'weak',
#  'fantastic',
#  'mint',
#  'glass',
#  'vegetable',
#  'bulk',
#  'cheap',
#  'completely',
#  'stock',
#  'continue',
#  'child',
#  'granola',
#  'iced',
#  'opinion',
#  '30',
#  'mind',
#  'puppy',
#  'filling',
#  'five',
#  '24',
#  'rest',
#  'extremely',
#  'chewy',
#  'eaten',
#  'turn',
#  'sale',
#  'true',
#  'count',
#  'mine',
#  'hint',
#  'healthier',
#  'expect',
#  'waste',
#  'shipped',
#  'wellness',
#  'chai',
#  'excited',
#  'hit',
#  'stop',
#  'normal',
#  'batch',
#  '9',
#  'effect',
#  'told',
#  'within',
#  'dinner',
#  'liquid',
#  'taking',
#  'crunch',
#  'seemed',
#  'sold',
#  'certainly',
#  'world',
#  'break',
#  'anyway',
#  'twice',
#  'wait',
#  'sent',
#  'strawberry',
#  'called',
#  'call',
#  'mountain',
#  'level',
#  'sweetness',
#  'contain',
#  'shop',
#  'thick',
#  'today',
#  'fit',
#  'seller',
#  'veggie',
#  'entire',
#  'eats',
#  'weve',
#  'purchasing',
#  'seen',
#  'baking',
#  'together',
#  'tomato',
#  'creamy',
#  'set',
#  'chemical',
#  'normally',
#  'beat',
#  'reading',
#  'source',
#  'shipment',
#  'pick',
#  'difficult',
#  'cause',
#  'acid',
#  'lower',
#  'oat',
#  'berry',
#  'easier',
#  'christmas',
#  'supermarket',
#  'addition',
#  'drinker',
#  'delivered',
#  'stash',
#  'truly',
#  'tiny',
#  'blueberry',
#  'particular',
#  'hold',
#  'unless',
#  'area',
#  'offer',
#  'substitute',
#  'consistency',
#  'pure',
#  'licorice',
#  'decent',
#  'chili',
#  'become',
#  'vinegar',
#  'loose',
#  'oh',
#  'shake',
#  'stopped',
#  'caramel',
#  'sour',
#  'packed',
#  'matter',
#  'sort',
#  'stevia',
#  'worked',
#  'banana',
#  'throw',
#  'nutrition',
#  'baked',
#  'shelf',
#  'remember',
#  '16',
#  'simple',
#  'tuna',
#  'anymore',
#  'none',
#  'salmon',
#  'flavoring',
#  'brewed',
#  'refreshing',
#  'total',
#  'description',
#  'ball',
#  'immediately',
#  'garlic',
#  'okay',
#  'discovered',
#  'stale',
#  'person',
#  'felt',
#  'newman',
#  'finish',
#  'totally',
#  'state',
#  'website',
#  'whatever',
#  'combination',
#  'condition',
#  'fun',
#  'crazy',
#  'training',
#  'including',
#  'serve',
#  'microwave',
#  'thinking',
#  'perhaps',
#  'complaint',
#  'plan',
#  'check',
#  'double',
#  'higher',
#  'broken',
#  'feeling',
#  's',
#  'cooked',
#  'thin',
#  'lover',
#  'pleasant',
#  '0',
#  'wet',
#  'he',
#  'coat',
#  '25',
#  'locally',
#  'hate',
#  'mom',
#  'finding',
#  'number',
#  'anywhere',
#  'kitchen',
#  'return',
#  'six',
#  'clear',
#  'bland',
#  'plant',
#  'dollar',
#  'stronger',
#  'beverage',
#  'blood',
#  'turned',
#  'sample',
#  'restaurant',
#  'yogurt',
#  'unlike',
#  'satisfying',
#  'mostly',
#  'perfectly',
#  'notice',
#  'horrible',
#  'supposed',
#  'roasted',
#  'kick',
#  'mess',
#  'wow',
#  'research',
#  'touch',
#  'e',
#  'short',
#  'except',
#  'standard',
#  'adult',
#  'individual',
#  'nearly',
#  'portion',
#  'craving',
#  'drop',
#  'changed',
#  'fill',
#  'brewer',
#  'reasonable',
#  'brewing',
#  'word',
#  'supplement',
#  'picture',
#  '00',
#  'ready',
#  'hazelnut',
#  'style',
#  'somewhat',
#  'stand',
#  'raspberry',
#  'warm',
#  'pumpkin',
#  'quantity',
#  'awful',
#  'bring',
#  'balance',
#  '11',
#  'crisp',
#  'carbs',
#  'avoid',
#  'pretzel',
#  'lime',
#  'pricey',
#  'nutritional',
#  'compare',
#  'china',
#  'heavy',
#  'system',
#  'control',
#  'near',
#  'expecting',
#  'c',
#  'hoping',
#  'terrible',
#  'us',
#  'future',
#  'pancake',
#  'carb',
#  'eater',
#  'listed',
#  'premium',
#  'test',
#  'moist',
#  'chewing',
#  'important',
#  'pie',
#  'fairly',
#  'onion',
#  'form',
#  'site',
#  'satisfied',
#  'italian',
#  'sea',
#  'impressed',
#  'trip',
#  'priced',
#  'summer',
#  'shes',
#  'sensitive',
#  'extract',
#  'sick',
#  'sandwich',
#  'hooked',
#  'animal',
#  'grey',
#  'mother',
#  'job',
#  'pocket',
#  'shape',
#  'fair',
#  'forward',
#  'supply',
#  'office',
#  'switch',
#  '99',
#  'switched',
#  'paid',
#  'agree',
#  'solid',
#  'show',
#  'mango',
#  'chunk',
#  'door',
#  'coming',
#  'pour',
#  'usual',
#  'afternoon',
#  'room',
#  'shot',
#  'straight',
#  'roll',
#  'yum',
#  'b',
#  'rating',
#  'biscuit',
#  'turkey',
#  'knew',
#  'direction',
#  'replacement',
#  'sitting',
#  'vegan',
#  'process',
#  'consider',
#  'sealed',
#  'heard',
#  'outside',
#  'alone',
#  'known',
#  'convenience',
#  'instruction',
#  'ship',
#  'kept',
#  'update',
#  'kibble',
#  'dressing',
#  'personally',
#  'heart',
#  'peach',
#  'cool',
#  'ended',
#  'subtle',
#  'sized',
#  'running',
#  'wrapped',
#  '40',
#  'earl',
#  'tend',
#  'dessert',
#  'figured',
#  'opening',
#  'worry',
#  'paper',
#  'actual',
#  'science',
#  'claim',
#  'matcha',
#  'raisin',
#  'lost',
#  'putting',
#  'chance',
#  'gourmet',
#  'manufacturer',
#  'kettle',
#  'homemade',
#  'wine',
#  'overly',
#  'subscription',
#  'kitty',
#  'gas',
#  'plenty',
#  'tart',
#  'ask',
#  'expiration',
#  'sleep',
#  'maple',
#  'working',
#  'freeze',
#  'air',
#  'liver',
#  'splenda',
#  'basically',
#  'surprise',
#  'party',
#  'human',
#  'o',
#  'creamer',
#  'american',
#  'filled',
#  'fall',
#  'stuck',
#  'various',
#  'upon',
#  'possible',
#  'slight',
#  'boy',
#  'bbq',
#  'hungry',
#  'eye',
#  'tablespoon',
#  'mini',
#  'tin',
#  'amazon',
#  'trouble',
#  'everyday',
#  'nature',
#  'imagine',
#  'share',
#  'traditional',
#  'helped',
#  'magnesium',
#  'weird',
#  'offered',
#  'worst',
#  'lid',
#  'sorry',
#  'send',
#  'overpowering',
#  'spoon',
#  ...]

# %%
testnih = "I'm gonna go to the mall. You're coming?"
testnih.replace("'",'')
